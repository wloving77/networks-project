# %% [markdown]
# # Sandbox for Producing P4 Related Visualizations

# %%
from helpers_p4 import parse_latency_file, chunk_by_1000, plot_endhost_execution_times

# %%
file_path_p4_rtt = "../src/telemetry/p4/rtt/results/latency_results_rtt.txt"
file_path_p4_packet_counting = "../src/telemetry/p4/packet_counting/results/latency_results_packet_counting.txt"
file_path_p4_jitter = "../src/telemetry/p4/jitter/results/latency_results_jitter.txt"

rtt_values = chunk_by_1000(parse_latency_file(file_path_p4_rtt))
packet_counting_values = chunk_by_1000(parse_latency_file(file_path_p4_packet_counting))
jitter_values = chunk_by_1000(parse_latency_file(file_path_p4_jitter))

# %%
plot_endhost_execution_times(rtt_values, packet_counting_values, jitter_values)
